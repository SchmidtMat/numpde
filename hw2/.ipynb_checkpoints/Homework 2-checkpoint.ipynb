# %% [markdown]
# # Homework 2: Due 2018-09-30 Mathias Schmidt

# %% [markdown]
# Use a Chebyshev method to solve the second order ordinary differential equation
#
# \begin{equation*}
# u^{''}(t)+au^{'}(t)+bu(t) = f(t)
# \end{equation*}
#
# from $t=0$ to $t=1$ with initial conditions $u(0)=1$ and $u^{'}=0$.
#
# $1.$ Do a grid convergence study to test the accuracy of your method. <br>
# $2.$ Setting $f(t)=0$, experiment with the values $a$ and $b$ to identify two regimes with qualitatively different dynamics.

# %%
# %matplotlib inline
import numpy
from matplotlib import pyplot
pyplot.style.use('ggplot')

def vander_chebyshev(x, n=None):
    if n is None:
        n = len(x)
    T = numpy.ones((len(x), n))
    if n > 1:
        T[:,1] = x
    for k in range(2,n):
        T[:,k] = 2 * x * T[:,k-1] - T[:,k-2]
    return T

# %% [markdown]
# Shifted Chebyshev polynomials of the first kind are defined as $T_{n}^*=T_{n}(2x-1)$. Note that when the argument of the Chebyshev polynomial is in the range of 2x − 1 ∈ [−1,1] the argument of the shifted Chebyshev polynomial is x ∈ [0,1]. Similarly, one can define shifted polynomials for generic intervals [a,b].  <br>
# Using chain rule we receive: <br>$T_{n}^{' *}=2*T_{n}^{'}$ and $T_{n}^{'' *}=4*T_{n}^{''}$

# %%
def chebeval(z, n=None):
    """Build matrices to evaluate the n-term Chebyshev expansion and its derivatives at point(s) z"""
    z = numpy.array(z, ndmin=1)
    if n is None:
        n = len(z)
    Tz = vander_chebyshev(z, n)
    dTz = numpy.zeros_like(Tz)
    dTz[:,1] = 1
    dTz[:,2] = 4*z
    ddTz = numpy.zeros_like(Tz)
    ddTz[:,2] = 4
    for n in range(3,n):
        dTz[:,n]  = n * (2*Tz[:,n-1] + dTz[:,n-2]/(n-2))
        ddTz[:,n] = n * (2*dTz[:,n-1] + ddTz[:,n-2]/(n-2))
    return [Tz, 2*dTz, 4*ddTz]

# %%
def cosspace(a, b, n=50):
    return (a + b)/2 + (b - a)/2 * (numpy.cos(numpy.linspace(-numpy.pi, 0, n)))

# %%
def laplacian_cheb(n, rhsfunc, a, b):
    x = cosspace(0, 1, n+1)  # n+1 points is n "elements"
    T = chebeval(2*x-1)

    L = T[2]+a*T[1]+b*T[0]
    rhs = rhsfunc(x)
    
    # u(0)=1
    L[0] = T[0][0]
    rhs[0] = 1 
    # u'(0)=0
    L[1] = T[1][0] 
    rhs[1] = 0     
    
    return x, L.dot(numpy.linalg.inv(T[0])), rhs

# %% [markdown]
# An exact solution for this ODE was determined for the values $a=2$ and $b=1$.
# \begin{equation*}
# u_{exact}(t) = e^{-t}(t+1)
# \end{equation*}

# %%
def exact_solution(x):
    return numpy.e**(-x)*(x+1)

# %%
x, L, rhs = laplacian_cheb(30, lambda x: 0*x, 2, 1)

uu = numpy.linalg.solve(L, rhs)
pyplot.plot(x, uu, 'o')

x1 = numpy.linspace(0,1,200)
pyplot.plot(x1,exact_solution(x1))

# %% [markdown]
# ### Grid refinement study

# %% [markdown]
# The grid refinement study is done using the following valued for a and b: $a=2$ and $b=1$. The exact solution is given above.

# %%
def mms_error(n, discretize, exact_solution):
    x, L, f = discretize(n, lambda x: 0*x, 2, 1)
    u = numpy.linalg.solve(L, f)
    return numpy.linalg.norm(u - exact_solution(x), numpy.inf)

# %%
ns = numpy.arange(2,40,2)

errors = [mms_error(n, laplacian_cheb, exact_solution) for n in ns]
pyplot.figure()
pyplot.semilogy(ns, errors, 'o', label='numerical')
for p in range(1,5):
    pyplot.semilogy(ns, 1/ns**(p), label='$n^{-%d}$'%p)
pyplot.xlabel('n')
pyplot.ylabel('error')
pyplot.legend(loc='lower left');

# %% [markdown]
# The grid refinement study shows that the error decreases with refinment upt to an n of 12. From this point on grid refinment is not beneficial anymore.

# %% [markdown]
# ### Setting f(t)=0, experiment with the values a and b to identify two regimes with qualitatively different dynamics.

# %% [markdown]
# The given ODE is an ODE of type second-order, linear, inhomogeneous, constant coefficients.
# \begin{equation*}
# u^{''}(t)+au^{'}(t)+bu(t) = 0
# \end{equation*}
# Such an equation has two regimes with qualitatively different dynamics.
# \begin{equation*}
# a^2 < 4*b
# \end{equation*}
# and
# \begin{equation*}
# a^2 > 4*b
# \end{equation*}
# Three settings are chosen. $a=1$ and $b=100$ for the first case. $a=10$ and $b=1$ for the second case and $a=2$,$b=1$ for the case where $a^2 = 4*b$ <br>
# In physics this cases are called underdamped, overdamped and critically damped

# %%
a_s = [(1),(10),(2)]
b_s = [(100),(1),(1)]

for nn in range(len(a_s)):
    a, b = a_s[nn], b_s[nn]
    x, L, rhs = laplacian_cheb(50, lambda x: 0*x, a, b)
    u = numpy.linalg.solve(L, rhs)
    pyplot.plot(x,u, label=nn)
pyplot.legend(loc='lower left')
